# %%
print('hellow')
# Out:
# hellow

# %%
##What is the minimum ,maximum and avarage imbd_rating for all movies
#same thing for bollywood movies and same things for hollywood movies

# %%
import csv
import os

# %%
os.chdir(r"C:\Users\ishra\Downloads\chapter_3_assets\1_intro")
   with open("movies.csv") as f:
   data=list(csv.reader(f)) 
    header=data[0]
    data=data[1:]

def calculate_reating_stats(data, indursty =None):
    ratings = []
    for row in data:
        if row[3] != 'NULL' and (industry is None or row[1]==indurstry):
            ratings.append(float(row[3]))
            
     max_rating=max(ratings)
     min_rating=min(ratings)
     avg_rating=sum(ratings)/len(ratings)
     return max_rating,min_rating,avg_rating


    max_rating,min_rating,avg_rating=calculate_reating_stats(data,indursty="Bollywood")
    print(f"All records: Max rating={max_rating},Min rating={min_rating},Avg rating={avg_rating}")
# Out:
#   File <string>:13
#     max_rating=max(ratings)
#                            ^
# IndentationError: unindent does not match any outer indentation level
