# %% [markdown]
# <a href="https://colab.research.google.com/github/khodezatulk/basic_pd/blob/main/home_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model
import math

# %% [markdown]
# ##price=m1*arear+m2*bedrooms+m3*age+b
# #area,bedrooms,age is independent variable and it's called feature.
# #price is dependent variable,m1,m2,m3 is called cofficient
# #d is the intercept

# %%
df=pd.read_csv('/content/drive/MyDrive/Machine_learning/homeprices.csv')
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
median_bedrooms=df.bedrooms.median()
median_bedrooms
# Out:
# 4.0

# %%
median_bedrooms=df.bedrooms.median()
df.bedrooms=df.bedrooms.fillna(median_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
#linerar rigration object
reg=sklearn.linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
#This is the value of m1,m2,m3
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
#value of intercept
reg.intercept_
# Out:
# np.float64(221323.00186540396)

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([498408.25158031])
